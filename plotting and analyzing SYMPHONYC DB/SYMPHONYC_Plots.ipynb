# %% [markdown]
# ## Connecting my Database to the Jupyter Notebook and plot the data with the Matplot library!

# %% [markdown]
# ## Import the required libraries:

# %%
import pandas as pd
import pandas.io.sql as sqlio
import psycopg2 as ps
from IPython.core.display_functions import display
import matplotlib.pyplot as plt
plt.close("all")
import networkx as nx

# %% [markdown]
# ## connect to the postgres:

# %%
db = ps.connect(
                dbname = "SYMPHONYC DB",
                user = "postgres",
                password = "password",
                host = "localhost",
                port = "5432",
                options = '-c search_path="SYMPHONYC"'
)

# %% [markdown]
# ## select * of artist table:

# %%
sql_select_all_artist = """
                    SELECT *
                        FROM artist
"""

# %%
artist_df = sqlio.read_sql_query(sql_select_all_artist, db)
artist_df_pie = artist_df.set_index('username')
# Out:
# d:\lms\4001\database\exercises & projects\symphonyc plots\venv\lib\site-packages\pandas\io\sql.py:758: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
display(artist_df)
# Out:
#    username  monthly_listeners  rank  \
# 0        31             374430     1
# 1        32             902667     2
# 2        33             281588     3
# 3        34             877688     4
# 4        35             945970     5
# 5        36             351936     6
# 6        37             641160     7
# 7        38             732119     8
# 8        39             845226     9
# 9        40             105137    10
# 10       41             195299    11
# 11       42             382569    12
# 12       43              42979    13
# 13       44             566799    14
# 14       45             291909    15
# 15       46             236427    16
# 16       47             762491    17
# 17       48             896404    18
# 18       49             365086    19
# 19       50             468522    20
#
#                                      social_media_url
# 0                  cnn.com/metus/aenean/fermentum.jsp
# 1    engadget.com/rhoncus/sed/vestibulum/sit/amet.png
# 2   tamu.edu/fusce/congue/diam/id/ornare/imperdiet...
# 3                    wiley.com/primis/in/faucibus.xml
# 4                                   youtu.be/amet.jpg
# 5                             addtoany.com/felis.json
# 6   reuters.com/morbi/quis/tortor/id/nulla/ultrice...
# 7          squidoo.com/elit/proin/interdum/mauris.png
# 8                  dot.gov/lobortis/sapien/sapien.png
# 9                           pen.io/eu/felis/fusce.png
# 10  admin.ch/ac/neque/duis/bibendum/morbi/non/quam...
# 11                                 ucla.edu/odio.json
# 12                uiuc.edu/tempor/convallis/nulla.jsp
# 13                   nsw.gov.au/dictumst/maecenas.png
# 14                            pen.io/velit/donec.html
# 15   zdnet.com/aliquam/lacus/morbi/quis/tortor/id.xml
# 16  cbsnews.com/tincidunt/nulla/mollis/molestie/lo...
# 17                digg.com/in/felis/donec/semper.aspx
# 18                      yellowbook.com/ligula/sit.jsp
# 19                  google.es/vulputate/elementum.jpg

# %% [markdown]
# ## plot all artists:

# %%
artist_df.plot.bar(y='monthly_listeners', x='username', figsize=(7,7), color='DarkOrange')
plt.title("Chart of Artists vs. monthly_listeners")
plt.xlabel("Artists username")
plt.ylabel("number of monthly listeners")

artist_df.plot.scatter(y='monthly_listeners', x='username', figsize=(7,7), color='Yellow', s=80)
plt.title("Chart of Artists vs. monthly_listeners")
plt.xlabel("Artists username")
plt.ylabel("number of monthly listeners")

artist_df_pie.plot.pie(y='monthly_listeners', figsize=(12,12), autopct="%.2f", fontsize=16)
plt.title("Pie Chart of Artists vs. monthly_listeners in percent")
# Out:
# Text(0.5, 1.0, 'Pie Chart of Artists vs. monthly_listeners in percent')

# %% [markdown]
# ## select * of artist table ordered:

# %%
sql_select_all_artist_ordered = """
                    SELECT *
                        FROM artist
                        ORDER BY monthly_listeners DESC
"""
artist_ordered_df = sqlio.read_sql_query(sql_select_all_artist_ordered, db)
artist_ordered_df_pie = artist_df.set_index('username')
display(artist_ordered_df)
# Out:
# d:\lms\4001\database\exercises & projects\symphonyc plots\venv\lib\site-packages\pandas\io\sql.py:758: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    username  monthly_listeners  rank  \
# 0        35             945970     5
# 1        32             902667     2
# 2        48             896404    18
# 3        34             877688     4
# 4        39             845226     9
# 5        47             762491    17
# 6        38             732119     8
# 7        37             641160     7
# 8        44             566799    14
# 9        50             468522    20
# 10       42             382569    12
# 11       31             374430     1
# 12       49             365086    19
# 13       36             351936     6
# 14       45             291909    15
# 15       33             281588     3
# 16       46             236427    16
# 17       41             195299    11
# 18       40             105137    10
# 19       43              42979    13
#
#                                      social_media_url
# 0                                   youtu.be/amet.jpg
# 1    engadget.com/rhoncus/sed/vestibulum/sit/amet.png
# 2                 digg.com/in/felis/donec/semper.aspx
# 3                    wiley.com/primis/in/faucibus.xml
# 4                  dot.gov/lobortis/sapien/sapien.png
# 5   cbsnews.com/tincidunt/nulla/mollis/molestie/lo...
# 6          squidoo.com/elit/proin/interdum/mauris.png
# 7   reuters.com/morbi/quis/tortor/id/nulla/ultrice...
# 8                    nsw.gov.au/dictumst/maecenas.png
# 9                   google.es/vulputate/elementum.jpg
# 10                                 ucla.edu/odio.json
# 11                 cnn.com/metus/aenean/fermentum.jsp
# 12                      yellowbook.com/ligula/sit.jsp
# 13                            addtoany.com/felis.json
# 14                            pen.io/velit/donec.html
# 15  tamu.edu/fusce/congue/diam/id/ornare/imperdiet...
# 16   zdnet.com/aliquam/lacus/morbi/quis/tortor/id.xml
# 17  admin.ch/ac/neque/duis/bibendum/morbi/non/quam...
# 18                          pen.io/eu/felis/fusce.png
# 19                uiuc.edu/tempor/convallis/nulla.jsp

# %%
artist_ordered_df.plot.bar(y='monthly_listeners', x='username', figsize=(7,7), color='DarkOrange')
plt.title("Chart of Artists vs. monthly_listeners")
plt.xlabel("Artists username")
plt.ylabel("number of monthly listeners")

artist_ordered_df.plot.scatter(y='monthly_listeners', x='username', figsize=(7,7), color='Yellow', s=80)
plt.title("Chart of Artists vs. monthly_listeners")
plt.xlabel("Artists username")
plt.ylabel("number of monthly listeners")

artist_ordered_df_pie.plot.pie(y='monthly_listeners', figsize=(12,12), autopct="%.2f", fontsize=16)
plt.title("Pie Chart of Artists vs. monthly_listeners in percent")
# Out:
# Text(0.5, 1.0, 'Pie Chart of Artists vs. monthly_listeners in percent')

# %% [markdown]
# ## select * of albums table:

# %%
sql_select_all_albums = """
                    SELECT *
                        FROM album
"""
albums_df = sqlio.read_sql_query(sql_select_all_albums, db)
#albums_df_pie = artist_df.set_index('username')
display(albums_df)
# Out:
# d:\lms\4001\database\exercises & projects\symphonyc plots\venv\lib\site-packages\pandas\io\sql.py:758: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    album_id                          title artist_username album_length  \
# 0         1                       Outbreak              41     00:16:00
# 1         2                       C.H.U.D.              50     00:57:00
# 2         3            Final Destination 5              44     01:24:00
# 3         4                    Love Stinks              40     02:17:00
# 4         5             Flowing (Nagareru)              39     02:11:00
# ..      ...                            ...             ...          ...
# 95       96                          Felon              32     00:45:00
# 96       97  Angriest Man in Brooklyn, The              41     00:50:00
# 97       98       Initial D (Tau man ji D)              49     00:11:00
# 98       99                         Sliver              47     02:14:00
# 99      100                 Guardian Angel              38     00:09:00
#
#     number_of_likes                                          image_url  \
# 0           4320612  http://cdbaby.com/eget/orci/vehicula/condiment...
# 1           7170702  http://facebook.com/praesent/blandit/nam/nulla...
# 2           9630506                           http://zdnet.com/sed.jpg
# 3           1726356  http://craigslist.org/eleifend/pede/libero/qui...
# 4           9843112  https://typepad.com/quam/sollicitudin/vitae/co...
# ..              ...                                                ...
# 95          1544469  https://networksolutions.com/lacinia/eget/tinc...
# 96          2264021       http://soup.io/habitasse/platea/dictumst.jpg
# 97          6760801  http://webeden.co.uk/ut/massa/quis/augue/luctu...
# 98          6604725      http://disqus.com/felis/eu/sapien/cursus.html
# 99          9325190                http://whitehouse.gov/tincidunt.jpg
#
#    release_date
# 0    2000-04-09
# 1    2008-05-26
# 2    2008-02-13
# 3    2011-12-03
# 4    2008-08-15
# ..          ...
# 95   2008-06-07
# 96   2008-01-05
# 97   2005-07-27
# 98   2018-08-25
# 99   2004-06-21
#
# [100 rows x 7 columns]

# %%
albums_df.plot.scatter(y='release_date', x='artist_username', figsize=(18,7), color='red', s=50)
plt.title("Chart of Artists vs. their albums through the different years")
plt.xlabel("Artists username")
plt.ylabel("albums through the different years")
# Out:
# Text(0, 0.5, 'albums through the different years')

# %% [markdown]
# ## select * of following_list table:

# %%
sql_select_all_following_list = """
                    SELECT *
                        FROM following_list
"""
following_list_df = sqlio.read_sql_query(sql_select_all_following_list, db)
display(following_list_df)
# Out:
# d:\lms\4001\database\exercises & projects\symphonyc plots\venv\lib\site-packages\pandas\io\sql.py:758: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    follower target date_of_following
# 0        26     15        2021-03-03
# 1        12      4        2021-03-28
# 2        18     21        2020-10-12
# 3        23     12        2021-08-31
# 4         5     13        2021-07-14
# ..      ...    ...               ...
# 91       25     18        2020-08-15
# 92       26      3        2021-05-31
# 93       14     11        2020-04-02
# 94       18     11        2021-01-02
# 95       27      3        2020-11-18
#
# [96 rows x 3 columns]

# %%
graph = nx.from_pandas_edgelist(following_list_df, 'follower', 'target')
plt.figure(figsize=(18, 18))
nx.draw(graph, with_labels=True, arrows=True, node_size=1500, font_size=23, font_color="red", font_weight="bold")
plt.title("Followers & Following graph network")
# Out:
# Text(0.5, 1.0, 'Followers & Following graph network')

# %% [markdown]
# ## song join album table:

# %%
sql_song_join_album = """
                    SELECT *
	                    FROM song INNER JOIN album USING (album_id)
	                    WHERE artist_username = '32'
	                    ORDER BY album_id
"""
song_join_album_df = sqlio.read_sql_query(sql_song_join_album, db)
song_join_album_df.rename(columns={"number_of_times_played": "number of times song played", "number_of_likes": "number of likes its album has"}, inplace= True)
display(song_join_album_df)
# Out:
# d:\lms\4001\database\exercises & projects\symphonyc plots\venv\lib\site-packages\pandas\io\sql.py:758: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    album_id song_id                           title song_length  \
# 0        10     100          Coulter's Brickellbush    00:10:00
# 1        10     167              Herpetineuron Moss    00:07:00
# 2        10       1          Yellow Water Buttercup    00:02:00
# 3        10     160          Delicate Thuidium Moss    00:00:00
# 4        10     349                   Bitter Cherry    00:01:00
# 5        28     338                  Sierra Wildrye    00:06:00
# 6        28       8               Dictyonema Lichen    00:06:00
# 7        28     463       Tomentose Groutiella Moss    00:08:00
# 8        28     192                        Oxtongue    00:00:00
# 9        62     407              Shrubby Woodsorrel    00:02:00
# 10       62     357           Largebracted Plantain    00:08:00
# 11       62     389        Hyacinth-flower Clematis    00:08:00
# 12       62     215              White Prairie Rose    00:00:00
# 13        8     489              Sonoma Spineflower    00:09:00
# 14        8      21               Northern Beantree    00:06:00
# 15        8     103             Narrowleaf Cowwheat    00:00:00
# 16        8     150         Texas Crested Coralroot    00:06:00
# 17        8     185                    Showy Cappel    00:06:00
# 18        8     218                  Brownish Sedge    00:00:00
# 19        8     307             Woolly Beachheather    00:03:00
# 20        8     341                      Yellow-box    00:11:00
# 21       85     312            Louisiana Rim Lichen    00:08:00
# 22       85     270                      Joinvillea    00:03:00
# 23       85     412             Woolly Goat Chicory    00:10:00
# 24       85     257            Slender Blazing Star    00:05:00
# 25       85     138                  Sandplain Flax    00:00:00
# 26       85     327                  Fall Dandelion    00:11:00
# 27       96     324                  Rush Pussytoes    00:11:00
# 28       96     340           Intermediate Paspalum    00:10:00
# 29       96      93  Baltimore Flavoparmelia Lichen    00:00:00
# 30       96     169           California Butterwort    00:03:00
# 31       96     154                 Splashzone Moss    00:08:00
# 32       96     454                        Villalba    00:00:00
#
#                                              song_url  \
# 0                          https://1und1.de/sapien.js
# 1   https://taobao.com/convallis/nulla/neque/liber...
# 2                           http://nytimes.com/sem.js
# 3    https://ucla.edu/nulla/pede/ullamcorper/augue.js
# 4   http://nhs.uk/amet/nunc/viverra/dapibus/nulla....
# 5   https://amazonaws.com/consequat/ut/nulla/sed/a...
# 6                         https://spotify.com/sit.xml
# 7                https://loc.gov/fermentum/donec.html
# 8   http://themeforest.net/vitae/mattis/nibh/ligul...
# 9   http://omniture.com/eros/viverra/eget/congue/e...
# 10  http://howstuffworks.com/in/faucibus/orci/luct...
# 11               https://youtube.com/etiam/pretium.js
# 12          https://latimes.com/enim/lorem/ipsum.html
# 13  https://joomla.org/molestie/sed/justo/pellente...
# 14             http://is.gd/vulputate/ut/ultrices.xml
# 15                     https://yahoo.co.jp/sapien.xml
# 16  http://weather.com/luctus/nec/molestie/sed/jus...
# 17  https://livejournal.com/cubilia/curae/nulla/da...
# 18   http://webs.com/sapien/iaculis/congue/vivamus.js
# 19      https://businessinsider.com/eget/eleifend.jsp
# 20  http://google.com.hk/volutpat/in/congue/etiam/...
# 21       https://twitter.com/donec/vitae/nisi/nam.jpg
# 22  http://flavors.me/sit/amet/lobortis/sapien/sap...
# 23        http://bandcamp.com/curabitur/convallis.jsp
# 24  http://constantcontact.com/massa/id/lobortis/c...
# 25                         https://1688.com/cras.html
# 26  https://google.com.hk/id/nisl/venenatis/lacini...
# 27      http://phoca.cz/convallis/duis/consequat.json
# 28     http://cyberchimps.com/et/ultrices/posuere.png
# 29  http://buzzfeed.com/vivamus/vestibulum/sagitti...
# 30             http://plala.or.jp/quisque/ut/erat.png
# 31  https://cloudflare.com/nam/nulla/integer/pede/...
# 32  https://cdbaby.com/sed/augue/aliquam/erat/volu...
#
#     number of times song played                                      title  \
# 0                       3623198              Tucker: The Man and His Dream
# 1                       1242246              Tucker: The Man and His Dream
# 2                       1214888              Tucker: The Man and His Dream
# 3                       2062357              Tucker: The Man and His Dream
# 4                       3466771              Tucker: The Man and His Dream
# 5                       4772619                                Keeping Mum
# 6                       5280615                                Keeping Mum
# 7                        637876                                Keeping Mum
# 8                       6915116                                Keeping Mum
# 9                       3859641                                    Nowhere
# 10                      1953591                                    Nowhere
# 11                      1740162                                    Nowhere
# 12                      9635433                                    Nowhere
# 13                      3436118  Best Man, The (Testimone dello sposo, Il)
# 14                      4770843  Best Man, The (Testimone dello sposo, Il)
# 15                      9124001  Best Man, The (Testimone dello sposo, Il)
# 16                      6055902  Best Man, The (Testimone dello sposo, Il)
# 17                      5608211  Best Man, The (Testimone dello sposo, Il)
# 18                      8826869  Best Man, The (Testimone dello sposo, Il)
# 19                      1876586  Best Man, The (Testimone dello sposo, Il)
# 20                      5876419  Best Man, The (Testimone dello sposo, Il)
# 21                      2888450                                       Prom
# 22                      9633402                                       Prom
# 23                       458459                                       Prom
# 24                      4108135                                       Prom
# 25                       889159                                       Prom
# 26                      1000804                                       Prom
# 27                      5347951                                      Felon
# 28                      5321757                                      Felon
# 29                      5144960                                      Felon
# 30                      3363501                                      Felon
# 31                       805729                                      Felon
# 32                      3256202                                      Felon
#
#    artist_username album_length  number of likes its album has  \
# 0               32     00:14:00                        6001619
# 1               32     00:14:00                        6001619
# 2               32     00:14:00                        6001619
# 3               32     00:14:00                        6001619
# 4               32     00:14:00                        6001619
# 5               32     01:51:00                        6739212
# 6               32     01:51:00                        6739212
# 7               32     01:51:00                        6739212
# 8               32     01:51:00                        6739212
# 9               32     01:40:00                        9446619
# 10              32     01:40:00                        9446619
# 11              32     01:40:00                        9446619
# 12              32     01:40:00                        9446619
# 13              32     01:18:00                        4158906
# 14              32     01:18:00                        4158906
# 15              32     01:18:00                        4158906
# 16              32     01:18:00                        4158906
# 17              32     01:18:00                        4158906
# 18              32     01:18:00                        4158906
# 19              32     01:18:00                        4158906
# 20              32     01:18:00                        4158906
# 21              32     00:35:00                        5786925
# 22              32     00:35:00                        5786925
# 23              32     00:35:00                        5786925
# 24              32     00:35:00                        5786925
# 25              32     00:35:00                        5786925
# 26              32     00:35:00                        5786925
# 27              32     00:45:00                        1544469
# 28              32     00:45:00                        1544469
# 29              32     00:45:00                        1544469
# 30              32     00:45:00                        1544469
# 31              32     00:45:00                        1544469
# 32              32     00:45:00                        1544469
#
#                                             image_url release_date
# 0                        http://mapquest.com/quis.png   2000-02-29
# 1                        http://mapquest.com/quis.png   2000-02-29
# 2                        http://mapquest.com/quis.png   2000-02-29
# 3                        http://mapquest.com/quis.png   2000-02-29
# 4                        http://mapquest.com/quis.png   2000-02-29
# 5   http://sciencedaily.com/risus/dapibus/augue/ve...   2012-09-28
# 6   http://sciencedaily.com/risus/dapibus/augue/ve...   2012-09-28
# 7   http://sciencedaily.com/risus/dapibus/augue/ve...   2012-09-28
# 8   http://sciencedaily.com/risus/dapibus/augue/ve...   2012-09-28
# 9                         http://ftc.gov/diam/nam.png   2005-02-07
# 10                        http://ftc.gov/diam/nam.png   2005-02-07
# 11                        http://ftc.gov/diam/nam.png   2005-02-07
# 12                        http://ftc.gov/diam/nam.png   2005-02-07
# 13       https://amazon.co.jp/viverra/diam/vitae.aspx   2004-06-11
# 14       https://amazon.co.jp/viverra/diam/vitae.aspx   2004-06-11
# 15       https://amazon.co.jp/viverra/diam/vitae.aspx   2004-06-11
# 16       https://amazon.co.jp/viverra/diam/vitae.aspx   2004-06-11
# 17       https://amazon.co.jp/viverra/diam/vitae.aspx   2004-06-11
# 18       https://amazon.co.jp/viverra/diam/vitae.aspx   2004-06-11
# 19       https://amazon.co.jp/viverra/diam/vitae.aspx   2004-06-11
# 20       https://amazon.co.jp/viverra/diam/vitae.aspx   2004-06-11
# 21    http://acquirethisname.com/congue/elementum.png   2007-11-13
# 22    http://acquirethisname.com/congue/elementum.png   2007-11-13
# 23    http://acquirethisname.com/congue/elementum.png   2007-11-13
# 24    http://acquirethisname.com/congue/elementum.png   2007-11-13
# 25    http://acquirethisname.com/congue/elementum.png   2007-11-13
# 26    http://acquirethisname.com/congue/elementum.png   2007-11-13
# 27  https://networksolutions.com/lacinia/eget/tinc...   2008-06-07
# 28  https://networksolutions.com/lacinia/eget/tinc...   2008-06-07
# 29  https://networksolutions.com/lacinia/eget/tinc...   2008-06-07
# 30  https://networksolutions.com/lacinia/eget/tinc...   2008-06-07
# 31  https://networksolutions.com/lacinia/eget/tinc...   2008-06-07
# 32  https://networksolutions.com/lacinia/eget/tinc...   2008-06-07

# %%
song_join_album_df.plot.bar(x='song_id', y=['number of times song played','number of likes its album has'] , figsize=(18,7))
plt.title("Chart of Artists vs. their work stats")
plt.xlabel("Song ID")
plt.ylabel("Number of: ")
# Out:
# Text(0, 0.5, 'Number of: ')
